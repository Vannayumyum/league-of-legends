# %% [markdown]
# # Web scrapping on op.gg

# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import urllib.request

# %%
url='https://www.op.gg/leaderboards/tier?region=euw'

# %%
page=urllib.request.urlopen(url,timeout=5)

# %%
soup=bs(page)

# %%
#Extracting summoner's names
name= soup.find_all('strong',{'class': 'summoner-name'})

# %%
sum_name=[]
for e in name :
    e=e.text
    e=e.replace('\n','')
    sum_name.append(e)

# %%
#Extracting number of LP
lp=soup.find_all('td',{'class': 'css-1oq0a1y e1g3wlsd6'})

# %%
lp_list=[]
for e in lp :
    e=e.text
    e=e.replace('\n','')
    lp_list.append(e)

# %%
#Extracting win/rate
ratio=soup.find_all('div',{'class': 'text'})
wr=[]
for e in ratio :
    e=e.text
    e=e.replace('\n','')
    wr.append(e)

# %%
#We create a dataframe
chall_ladder=[]
for i in range(len(sum_name)):
    info_row={}
    info_row['Summoner name']=sum_name[i]
    info_row['LP']=lp_list[i]
    info_row['Winrate']=wr[i]
    chall_ladder.append(info_row)

# %%
df=pd.DataFrame(chall_ladder)

# %%
pd.set_option('display.max_rows', df.shape[0]+1)
df
# Out:
#        Summoner name        LP Winrate
# 0     Razørk Activoo  1,756 LP     57%
# 1    ViV NEXT ADKING  1,745 LP     58%
# 2        Thumbs Down  1,647 LP     57%
# 3             DzuUwU  1,639 LP     60%
# 4   I Love Uber Eats  1,624 LP     54%
# 5              Noah7  1,622 LP     59%
# 6    S P L A S H 777  1,622 LP     54%
# 7      4321455213123  1,604 LP     62%
# 8    the inescapable  1,589 LP     60%
# 9        Odysseus131  1,557 LP     56%
# 10         Beanovich  1,499 LP     54%
# 11     bigboynumbers  1,485 LP     58%
# 12  supaaaaaaaaaaaaa  1,474 LP     56%
# 13             Stend  1,447 LP     60%
# 14   Twitch Sinerias  1,444 LP     57%
# 15        BDS xMatty  1,434 LP     57%
# 16     school phobia  1,432 LP     55%
# 17   PORTUGUESE GALA  1,407 LP     54%
# 18       Road2Narnia  1,406 LP     56%
# 19      TakeSet sama  1,404 LP     56%
# 20      pocovirtuoso  1,397 LP     55%
# 21         Riven PhD  1,391 LP     66%
# 22        Villager C  1,377 LP     54%
# 23       LPG ZAMULEK  1,374 LP     60%
# 24               zyb  1,353 LP     55%
# 25           Groinze  1,348 LP     60%
# 26             FΙGHT  1,346 LP     56%
# 27         primeee21  1,343 LP     59%
# 28           Dam ADC  1,339 LP     55%
# 29          ANDARlEL  1,332 LP     56%
# 30  shunsui kyoraku1  1,331 LP     54%
# 31       Badlulu fan  1,328 LP     56%
# 32         sanghyxxn  1,326 LP     56%
# 33        TH Krillin  1,325 LP     55%
# 34       Me Wo Akeru  1,322 LP     54%
# 35      Faker SIayer  1,319 LP     54%
# 36       on the fire  1,318 LP     60%
# 37  RobertBrännström  1,315 LP     55%
# 38          Sexelent  1,314 LP     54%
# 39            Lekcyc  1,302 LP     63%
# 40        Ale369Zika  1,301 LP     63%
# 41               FGG  1,298 LP     54%
# 42               ACD  1,291 LP     57%
# 43            Noeyim  1,288 LP     67%
# 44     Horse Tongue   1,288 LP     60%
# 45   Gumayusi Slayer  1,282 LP     59%
# 46    Rabble Arouser  1,280 LP     57%
# 47       Albetrayber  1,275 LP     63%
# 48         GO lyncas  1,272 LP     54%
# 49           Photon1  1,268 LP     58%
# 50          Hawkellα  1,268 LP     52%
# 51             EMDDD  1,265 LP     54%
# 52       WAO RANK 1   1,264 LP     53%
# 53     GO toucouille  1,263 LP     55%
# 54          Been you  1,260 LP     58%
# 55           Maynter  1,258 LP     57%
# 56  Just an engineer  1,258 LP     57%
# 57     Anabolic Top1  1,252 LP     59%
# 58         avarice61  1,246 LP     52%
# 59    i wanna go msi  1,242 LP     62%
# 60            Sebekx  1,240 LP     57%
# 61          xLinayaa  1,237 LP     64%
# 62       HAHAHAHHAHA  1,237 LP     54%
# 63        KC SAKEN12  1,236 LP     55%
# 64      Keria Slayer  1,233 LP     53%
# 65           FUN k3y  1,222 LP     59%
# 66           dajor25  1,221 LP     57%
# 67            aII mb  1,220 LP     53%
# 68      its not over  1,215 LP     63%
# 69             Kenal  1,212 LP     53%
# 70       innerbloom2  1,209 LP     55%
# 71          dehastee  1,206 LP     57%
# 72      motus vetiti  1,203 LP     57%
# 73         NattyNatt  1,203 LP     53%
# 74   TwTv Kaos Angel  1,203 LP     56%
# 75  disciplinfreedom  1,202 LP     62%
# 76  Wesley Warren Jr  1,198 LP     54%
# 77     FNC Hylissang  1,197 LP     53%
# 78           RXBXCXP  1,197 LP     60%
# 79        derfiddIer  1,196 LP     52%
# 80          Practice  1,195 LP     56%
# 81          AHaHaCiK  1,195 LP     54%
# 82       INTOXICATΕD  1,183 LP     55%
# 83       Mr Robinson  1,180 LP     54%
# 84  Strawberrys Wake  1,175 LP     59%
# 85  Sinkingendle5sly  1,175 LP     54%
# 86            Jαvier  1,173 LP     55%
# 87            zzzzqq  1,170 LP     55%
# 88          Speartan  1,170 LP     54%
# 89            RKRKZN  1,162 LP     53%
# 90        EL RONRONS  1,158 LP     56%
# 91            SBSKSB  1,157 LP     54%
# 92      TwTVxKenzuke  1,155 LP     52%
# 93         LIL Peyz1  1,155 LP     54%
# 94            Notiko  1,154 LP     55%
# 95            SlNGED  1,153 LP     53%
# 96         SUP Serin  1,151 LP     53%
# 97      yarr agriyor  1,150 LP     55%
# 98    oiushdfkjsdfsd  1,142 LP     53%
# 99         Badlulu00  1,142 LP     55%

# %%
df.to_csv('euw_100_challengers', index=False)
