# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import urllib.request

# %%
url='https://www.op.gg/leaderboards/tier?region=euw'

# %%
page=urllib.request.urlopen(url,timeout=5)

# %%
soup=bs(page)

# %%
#Extracting summoner's names
name= soup.find_all('strong',{'class': 'summoner-name'})

# %%
sum_name=[]
for e in prod :
    e=e.text
    e=e.replace('\n','')
    sum_name.append(e)

# %%
#Extracting number of LP
lp=soup.find_all('td',{'class': 'css-1oq0a1y e1g3wlsd6'})

# %%
lp_list=[]
for e in lp :
    e=e.text
    e=e.replace('\n','')
    lp_list.append(e)

# %%
#Extracting win/rate
ratio=soup.find_all('div',{'class': 'text'})
wr=[]
for e in ratio :
    e=e.text
    e=e.replace('\n','')
    wr.append(e)

# %%
#We create a dataframe
chall_ladder=[]
for i in range(len(sum_name)):
    info_row={}
    info_row['Summoner name']=sum_name[i]
    info_row['LP']=lp_list[i]
    info_row['Winrate']=wr[i]
    chall_ladder.append(info_row)

# %%
df=pd.DataFrame(chall_ladder)

# %%
pd.set_option('display.max_rows', df.shape[0]+1)
df
# Out:
#        Summoner name        LP Winrate
# 0     Razørk Activoo  1,730 LP     57%
# 1    ViV NEXT ADKING  1,719 LP     57%
# 2   I Love Uber Eats  1,658 LP     55%
# 3             DzuUwU  1,639 LP     60%
# 4      4321455213123  1,630 LP     63%
# 5              Noah7  1,591 LP     59%
# 6    the inescapable  1,589 LP     60%
# 7        Thumbs Down  1,570 LP     57%
# 8        Odysseus131  1,557 LP     56%
# 9    S P L A S H 777  1,551 LP     54%
# 10         Beanovich  1,497 LP     54%
# 11  supaaaaaaaaaaaaa  1,474 LP     56%
# 12   Twitch Sinerias  1,468 LP     57%
# 13     bigboynumbers  1,458 LP     58%
# 14       LPG ZAMULEK  1,434 LP     57%
# 15        BDS xMatty  1,427 LP     60%
# 16        Villager C  1,426 LP     54%
# 17         primeee21  1,413 LP     59%
# 18     school phobia  1,406 LP     55%
# 19       Road2Narnia  1,406 LP     56%
# 20       Badlulu fan  1,401 LP     57%
# 21             Stend  1,393 LP     60%
# 22         Riven PhD  1,391 LP     66%
# 23      TakeSet sama  1,380 LP     56%
# 24   PORTUGUESE GALA  1,361 LP     53%
# 25               zyb  1,353 LP     55%
# 26      pocovirtuoso  1,348 LP     55%
# 27  shunsui kyoraku1  1,341 LP     56%
# 28        TH Krillin  1,329 LP     54%
# 29          Sexelent  1,325 LP     55%
# 30       Me Wo Akeru  1,322 LP     54%
# 31      Faker SIayer  1,322 LP     54%
# 32       on the fire  1,319 LP     54%
# 33  RobertBrännström  1,318 LP     60%
# 34         sanghyxxn  1,315 LP     55%
# 35               FGG  1,314 LP     55%
# 36            Lekcyc  1,307 LP     56%
# 37             FΙGHT  1,305 LP     54%
# 38           Photon1  1,302 LP     63%
# 39         avarice61  1,301 LP     59%
# 40               ACD  1,300 LP     56%
# 41             EMDDD  1,297 LP     52%
# 42           Dam ADC  1,293 LP     58%
# 43       WAO RANK 1   1,291 LP     57%
# 44     Horse Tongue   1,290 LP     54%
# 45          ANDARlEL  1,288 LP     53%
# 46   Gumayusi Slayer  1,288 LP     60%
# 47    Rabble Arouser  1,282 LP     59%
# 48       Albetrayber  1,280 LP     57%
# 49        Ale369Zika  1,276 LP     63%
# 50           Groinze  1,275 LP     63%
# 51    i wanna go msi  1,271 LP     59%
# 52  Just an engineer  1,267 LP     62%
# 53            Noeyim  1,259 LP     54%
# 54        Deli Velet  1,258 LP     57%
# 55      its not over  1,256 LP     67%
# 56            Sebekx  1,240 LP     63%
# 57     GO toucouille  1,240 LP     57%
# 58          xLinayaa  1,237 LP     55%
# 59           Maynter  1,237 LP     64%
# 60        KC SAKEN12  1,236 LP     57%
# 61      Keria Slayer  1,236 LP     55%
# 62         GO lyncas  1,235 LP     54%
# 63           FUN k3y  1,223 LP     54%
# 64          dehastee  1,222 LP     59%
# 65     FNC Hylissang  1,221 LP     54%
# 66       innerbloom2  1,212 LP     53%
# 67       HAHAHAHHAHA  1,211 LP     57%
# 68        EL RONRONS  1,209 LP     55%
# 69          Been you  1,205 LP     58%
# 70      motus vetiti  1,203 LP     57%
# 71  disciplinfreedom  1,202 LP     62%
# 72  Strawberrys Wake  1,201 LP     59%
# 73            aII mb  1,200 LP     56%
# 74      yarr agriyor  1,198 LP     53%
# 75           RXBXCXP  1,197 LP     60%
# 76  Sinkingendle5sly  1,197 LP     54%
# 77          Practice  1,195 LP     56%
# 78          AHaHaCiK  1,195 LP     54%
# 79             Kenal  1,182 LP     57%
# 80       Mr Robinson  1,180 LP     54%
# 81         NattyNatt  1,178 LP     53%
# 82   TwTv Kaos Angel  1,174 LP     55%
# 83            Jαvier  1,173 LP     55%
# 84  Wesley Warren Jr  1,170 LP     54%
# 85             Mαrth  1,165 LP     61%
# 86            zzzzqq  1,159 LP     55%
# 87          Hawkellα  1,158 LP     58%
# 88       INTOXICATΕD  1,156 LP     54%
# 89     Feel Immortal  1,154 LP     52%
# 90         LIL Peyz1  1,153 LP     53%
# 91            SlNGED  1,149 LP     53%
# 92          crawlzzz  1,147 LP     54%
# 93         SUP Serin  1,144 LP     55%
# 94          Speartan  1,142 LP     53%
# 95               soz  1,142 LP     52%
# 96    oiushdfkjsdfsd  1,142 LP     55%
# 97        derfiddIer  1,138 LP     56%
# 98         Badlulu00  1,138 LP     60%
# 99            Roison  1,138 LP     57%
